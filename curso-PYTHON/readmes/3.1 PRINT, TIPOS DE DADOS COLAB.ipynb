# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Função print()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print()
# Out:
# Running cells with 'c:\Users\Instrutor\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Instrutor/AppData/Local/Microsoft/WindowsApps/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
print("Python")
# Out:
# Running cells with 'c:\Users\Instrutor\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Instrutor/AppData/Local/Microsoft/WindowsApps/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
print("Curso de")
print("Python")
# Out:
# Running cells with 'c:\Users\Instrutor\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Instrutor/AppData/Local/Microsoft/WindowsApps/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# O resultado no console é dado por cada linha útil de programação
# Observe que pular a linha 3 não causa nenhuma ação para o console
print ("Curso de")

print ("Python")
# Out:
# Running cells with 'c:\Users\Instrutor\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Instrutor/AppData/Local/Microsoft/WindowsApps/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
print ("Curso de")
print() #Um print sem parâmetros pode ser usado para pular uma linha no console
print("Python")
# Out:
# Running cells with 'c:\Users\Instrutor\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Instrutor/AppData/Local/Microsoft/WindowsApps/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Out:
# Running cells with 'c:\Users\Instrutor\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Instrutor/AppData/Local/Microsoft/WindowsApps/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# # Tipos de dados

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(type("SENAI"))
# Out:
# Running cells with 'c:\Users\Instrutor\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Instrutor/AppData/Local/Microsoft/WindowsApps/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("Olá mundo")
print("123")
print(123)
print(1.23)
print(12e3)
print(True)
print(False)
# Out:
# Running cells with 'c:\Users\Instrutor\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Instrutor/AppData/Local/Microsoft/WindowsApps/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("Dia:",10,"Mês:",8,"Ano:",2023,"Temperatura:",25.7)
# Out:
# Running cells with 'c:\Users\Instrutor\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Instrutor/AppData/Local/Microsoft/WindowsApps/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Out:
# Running cells with 'c:\Users\Instrutor\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Instrutor/AppData/Local/Microsoft/WindowsApps/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Out:
# Running cells with 'c:\Users\Instrutor\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Instrutor/AppData/Local/Microsoft/WindowsApps/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# # Caracteres de escape

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("Escola SENAI \"Conde Alexandre Siciliano\"")
# Out:
# Running cells with 'c:\Users\Instrutor\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Instrutor/AppData/Local/Microsoft/WindowsApps/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
print("Caminho da pasta: c:\\Users\\Aluno")
# Out:
# Running cells with 'c:\Users\Instrutor\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Instrutor/AppData/Local/Microsoft/WindowsApps/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
print("Escola:\t\tSENAI\nCidade:\t\tJundiaí\nTelefone:\t1145236400")
# Out:
# Running cells with 'c:\Users\Instrutor\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Instrutor/AppData/Local/Microsoft/WindowsApps/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Out:
# Running cells with 'c:\Users\Instrutor\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Instrutor/AppData/Local/Microsoft/WindowsApps/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# # Outros parâmetros da função print()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("Dia:",10,"Mês:",8,"Ano:",2023)
# Out:
# Running cells with 'c:\Users\Instrutor\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Instrutor/AppData/Local/Microsoft/WindowsApps/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
print("Dia:",10,"Mês:",8,"Ano:",2023,sep="")
# Out:
# Running cells with 'c:\Users\Instrutor\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Instrutor/AppData/Local/Microsoft/WindowsApps/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
print("Dia:",10," Mês:",8," Ano:",2023,sep="")
# Out:
# Running cells with 'c:\Users\Instrutor\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Instrutor/AppData/Local/Microsoft/WindowsApps/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("Escola: ",end='')
print("SENAI")
# Out:
# Running cells with 'c:\Users\Instrutor\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Instrutor/AppData/Local/Microsoft/WindowsApps/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("Jundiaí é um município brasileiro do estado de São Paulo, onde localiza-se a região de Jundiaí (interior) do estado de São Paulo. Localiza-se a 23º11'11" de latitude sul e 46º53'03" de longitude oeste, a uma altitude de 762 metros.")
# Out:
# Running cells with 'c:\Users\Instrutor\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Instrutor/AppData/Local/Microsoft/WindowsApps/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# # Print com parâmetro multilinha

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print('''
Curso: Python
Escola: SENAI
Estado: São Paulo
''')
# Out:
# Running cells with 'c:\Users\Instrutor\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Instrutor/AppData/Local/Microsoft/WindowsApps/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ![image.png](data:image/png;base64,...)
